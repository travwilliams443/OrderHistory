# %%
import pandas as pd
import chromadb
from chromadb.utils import embedding_functions
import openai
import os
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document
from uuid import uuid4
import hashlib

# %%
df = pd.read_csv('Retail.OrderHistory.1.csv')

# %%
# Strip milliseconds from datetime
df['Order Date'] = df['Order Date'].str.replace(r'\.\d+', '', regex=True)

df['Order Date'] = pd.to_datetime(df['Order Date'], utc=True)

# %%
df_brief = df[['Order Date', 'Unit Price', 'Product Name', 'ASIN']]

# %%
df_small = df.sample(n=100)
#df_small = df.head(5)

# %%
df_brief_small = df_small[['Order Date', 'Unit Price', 'Product Name', 'ASIN']]

# %%
description_column = 'Product Name' 
asin_column = 'ASIN'
order_date_column = 'Order Date'

# %%
#df = df_brief_small

# %%
if os.getenv("OPENAI_API_KEY") is not None:
    openai.api_key = os.getenv("OPENAI_API_KEY")
    print ("OPENAI_API_KEY is ready")
else:
    print ("OPENAI_API_KEY environment variable not found")
# Out:
# OPENAI_API_KEY is ready

# %%
# Use OpenAI embeddings for vectorization
openai_embedding = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
# Initialize Chroma client
vector_store = Chroma(collection_name='amazon_products',persist_directory='./vectordb',embedding_function=openai_embedding)

# %%
# Generate a unique ID by hashing 'Order Date', 'Unit Price', and 'Product Name'
def generate_unique_id(row):
    unique_string = f"{row['Order Date']}_{row['Unit Price']}_{row['Product Name']}_{row['ASIN']}"
    return hashlib.md5(unique_string.encode()).hexdigest()

# %%
# Populate the vectore store
documents = []
uuids = []  # List to store UUIDs

# Loop through each row and use the generated unique ID
for index, row in df_to_store.iterrows():
    unique_id = generate_unique_id(row)
    description = row[description_column]
    
    if pd.notna(description):  # Ensure the description is not NaN
        
        # Create a Document object for each row
        document = Document(
            page_content=description,
            metadata={"Order Date": str(row['Order Date']), "Unit Price": row['Unit Price'], "Product Name": row['Product Name'], "ASIN": row['ASIN'], "Category": row['Category'], "Room": row['Room']},
            id=unique_id
        )
        
        # Add the document to the documents list
        documents.append(document)
        
        # Generate a UUID and add to the UUIDs list
        uuids.append(str(uuid4()))

# Add the documents to the vector store in bulk
vector_store.add_documents(documents=documents, ids=uuids)
# Out:
# ['fd08ba9a-39e2-4287-99f5-bbc29b213c14',
#  'e322c223-b81e-4476-9030-540dfdc06553',
#  'd4f2b9c7-4f33-445f-a6a9-c731f079882c',
#  '04d06b7a-113b-47cd-a596-a94f404bef5f',
#  'cb18fd1b-4b03-4223-8a92-6a7a4a9cfb01',
#  '1d4d570d-efee-489a-8710-8a3cbb085e94',
#  '552ddb38-15a2-45c8-9474-41ab7d0ad303',
#  '24da193c-d3b5-4ecd-8a5f-d33757ad4245',
#  'c247cd96-cea0-4339-9f86-43fb88e2baf4',
#  '12d2f983-0595-4c79-84a5-405303a8af17',
#  '9ca4d787-ba12-433f-9828-93ca3416276f',
#  'bd130c9e-89c9-4066-a226-45b4b2c877c9',
#  'e96eae57-33bc-415d-ae01-3a4cc5314885',
#  '50f238f0-ff90-44fc-bfcf-07d467e51197',
#  'ef946526-3a80-4b36-b4fb-ccc632232007',
#  'b2b8a38e-ddeb-45ca-ac1e-e961b62425aa',
#  '7b20ece1-9c61-4a76-bf17-a18cd13b603e',
#  'df52a0cb-1f0e-435a-8827-9f9072b1f16b',
#  '22bbc25f-a0d7-452b-86a5-33d0438d6e54',
#  'aa877f4f-5a3f-4745-8c7a-dea342a39750',
#  '64f0f331-e62b-4134-9892-fb2a5a6142ee',
#  '883fea30-eb33-4cc1-96a7-d5e225678fa3',
#  '5ffa3339-658a-43c0-a732-6a30a72bab89',
#  'f42de6fa-f67a-4c1a-863d-8e8dfa59786c',
#  '613fce07-2a2a-4eaf-b708-8776270d4c01',
#  'c299a43b-5fd2-487c-929d-87cec3830c96',
#  '1c989122-ead4-416d-982f-27b76744cc39',
#  '96963f28-eb7d-4ba0-82fe-879c8c78e8c7',
#  '417bc5de-a504-4d2e-adb3-0d9851f53776',
#  'f453bb3e-05f5-45f6-9625-81d21787a94c',
#  'd9e43134-5bb6-4b32-b6fb-ab0c119d8c3d',
#  'c9e2e8b5-85ad-46e7-90a3-156e0ecd010e',
#  '779773ab-b47a-40bd-91e9-f8cab87c9e4e',
#  '5c1da7b9-7504-4603-8b48-baf38e2495dc',
#  '64d8fb5f-0635-441e-9699-4c8fa3abc446',
#  'd7714f9c-f971-4a8e-a25f-bc521ecf925b',
#  'b03f053c-cf0b-4e07-9b5e-5f4dfe15498d',
#  '18ba3ca9-268d-4841-9c83-d6d491e8876b',
#  '6bfd1753-a156-4e27-8d20-ed70e43594b6',
#  '49608629-db51-4b77-a1a2-e619d093b598',
#  '9e0ff7f2-3c75-4fbc-8bc0-d2cfa5b7fcb4',
#  '4468109e-f335-4711-a55a-59ea9d015893',
#  'e30682d0-62e3-4bdd-8ab4-7145914bdda8',
#  'a8320b38-aea7-4adf-97ff-dc27a51ad745',
#  '21ffd959-135b-445c-9702-a95c7b410206',
#  '9f38a3b8-f896-4fd0-930c-099657c181cb',
#  'fc101f7a-4d28-4124-b9d6-9d7381acf56a',
#  '91b853fe-2f4d-4bcf-947e-ab2cad09b435',
#  'e5862ccf-8b9e-4daa-b249-9b11161cfeef',
#  'a57d1d91-8606-4c11-abf5-8c4df4e1419e',
#  'da3f25de-3af7-4a64-a9dd-8c05e56d5df0',
#  '5719cd11-e9af-48ce-ac84-3e4d90653ac4',
#  '8cab76e4-2445-4627-ab45-8146a775178f',
#  '1d3d17b0-c26d-491b-8814-2f8bd416ac5c',
#  '40b3832a-0999-4b07-b9d5-00d82ef849d4',
#  '8466f1d3-61fa-4573-a094-57b6e2150216',
#  'b195a80e-3f4f-4275-8493-1c2eb15566e9',
#  'fc68c126-814e-4af4-b877-86d9bbea0545',
#  '46dd55db-9874-4bae-9dae-82f722fb86a7',
#  '2f3ca661-71d3-46e5-aabf-812c3a78fadb',
#  'b407fe16-b122-4202-8f86-678cf0a64172',
#  '53f25b66-a8fe-40d9-ac94-a4ab49442b83',
#  'cf3e0818-1bb4-4edc-b0c6-7dc3b51131af',
#  '7b2b4143-d607-477f-9d6d-42490d568b70',
#  '263e62f9-5e69-4550-9a6a-3c2af4c706aa',
#  'e514db74-09e3-481e-a4fb-9d03944edcae',
#  '1ba8148b-15ef-4cff-b892-3f44cade9856',
#  '2d0b1348-e521-41f1-b4e9-55704f264346',
#  '22e0428b-ed27-445d-9def-e1177065403e',
#  '1213e3e9-6c28-4fdb-948a-40f356af2818',
#  'd13d1efe-c576-4114-af87-09d8afc9a17e',
#  '5e80e838-9296-4b1f-afd4-433c40682907',
#  '8f06e0de-8c9c-4b71-8a32-ebc54bf470d4',
#  'd7a5199e-def1-4a80-9b29-f6fe984adce6',
#  '5f7d6501-ada2-47ef-9eaa-544081b69ff9',
#  'c0c82296-3aa5-43d3-8221-a791667b1860',
#  '64da0509-9675-4cee-8be8-e41086ea65c9',
#  '012009a3-3015-4cab-87ed-95103ca59de4',
#  '859c775e-9580-4978-a281-0c39d87e79dc',
#  '1d252047-8435-4148-aea6-75da284b9765',
#  '09bee30b-bd3f-4035-b602-c1b4f447b361',
#  'c811089b-a0ac-4554-874c-cca669c4eece',
#  '7583c32d-5630-4fba-a456-a344cfeecca0',
#  'cc110fea-a604-4ea9-9099-19e3d8dafc76',
#  '7aaadc68-95cf-4709-9e66-7e13563440c2',
#  '805b2d23-5027-4581-9f7e-306e9131056f',
#  'd7bd23c6-90cb-466b-a848-1ad72340d752',
#  'f34de477-c1d9-4549-bad9-d4d95d01ddd7',
#  '5ec3526f-4fcb-4f7e-bb09-1380380f2bce',
#  'c9b04079-c500-4d02-87a6-4d3df2eb5f07',
#  '56af981e-40a6-4701-92c7-c60745a186f8',
#  'cb26b408-df76-4f78-abf8-4225b1e1e121',
#  '0e4f655c-d7ae-4d00-a698-50176550bb81',
#  'ebd53fcd-c947-4774-91cc-510bc1d84c78',
#  '548eb806-d103-44cd-862d-0eb3faaf822c',
#  'ac182d15-91de-4ce7-ae93-753a49876710',
#  '227eda9e-f4cb-40f8-af57-567a82397ab8',
#  '8eaf22e8-5978-4efa-a0b7-f3ae5d876ba6',
#  'e73e8c2e-4f8b-4871-b043-c77e0021c9c3',
#  'd514833a-0fbc-471f-ac9f-5256a01103b6',
#  'f2eef1f6-2537-4c2a-a5f6-0faa04382545',
#  '5e304f07-94c2-4c5f-980b-46a92b021a5e',
#  'ed63f8e6-451b-4194-9cd5-6fac71d47550',
#  '8d73a227-e255-4f0b-8b9d-bf6c6f9ef0a4',
#  '7d7f8a4a-ca1e-4d68-97cc-cda8e07a7f6e',
#  'f1aaa16a-ca66-46bf-b41c-b7b825f39bd2',
#  'fc700ff9-f731-475b-9f04-0806b3f71e70',
#  '7777b5a4-dd87-4138-946c-ad4651065b3c',
#  'f2c7b31b-8c9f-49d4-b2e9-15d458b20d6d',
#  '5120f4c2-41f3-43c4-8d40-b023d224c0b6',
#  'a4fe805c-f3f1-414c-998d-8b891d8753ed',
#  '37360cef-a521-471e-b00c-c85cd10d6d9b',
#  '3a3d2c22-a131-46d3-9999-44217f48e77d',
#  'b9ef8a4f-d1ba-4a0b-8ef4-77baf99cecb2',
#  '0372661b-d91b-4caf-93da-42328b03abba',
#  'f081aceb-25cf-46fd-9a51-33892db25c14',
#  '40e28044-4136-446b-b9a5-c6a2b3f2b34f',
#  'dc0a20f7-2d42-4da0-ba2e-372cb40bf262',
#  '5cb746d2-a23f-4cef-86f3-8e75396b329b',
#  '2196ff90-8129-426d-a851-03ed8e1c04dd',
#  'fa46c980-e959-4a71-9aa9-f7f42a3c8281',
#  'ac5de57b-4e27-48c6-a697-dc0b7c6c8ff5',
#  '0f8ae0a8-3462-4af8-8125-867085a2bfd8',
#  '47981f73-aaf7-4e3c-a28b-6869a0e36ee0',
#  '6c86fd26-0d0d-46cb-9aae-6a01896a3bc2',
#  'ab536ab5-6896-469d-b900-a82ee67b94f8',
#  'c7494cf7-ec58-4164-bc09-f96a2cb65091',
#  'd8bdd79b-e429-4a20-a89f-4786b8b476de',
#  '37c0d0b7-adff-4517-95a4-7ba680c853c9',
#  '2aa4375d-28eb-4b6c-85e6-2f66a10fdcbc',
#  '3c6d7377-8a31-4826-99fb-118690cfd6fa',
#  '7fadae3e-f461-49ff-8380-4f508ecc2a49',
#  'ae3d3d3f-6bbc-40db-b91f-fe49b920b43c',
#  'b6ec8cae-5f2a-4cf6-80e5-00b5431d600b',
#  'b7965f14-e372-41a8-b296-531ceed14ce8',
#  'ea4f07cb-489f-4e64-b283-8d2fd4eb9384',
#  '9169161a-fa0d-4d6f-992a-6a03d783c6af',
#  '88764e8d-f726-4ffb-8939-7a38b4f87cab',
#  '71748030-2a14-43fe-9ddf-248941425681',
#  '02f05c09-450c-4f29-94ae-9a86fb6b1691',
#  '9cd164f8-4426-4257-a8c8-b527e38b4fdc',
#  '63dac128-17e1-4805-ad9a-78d5ff7dc279',
#  '53984f75-677c-410d-8175-aa8a19cb513b',
#  '1e6cae84-8086-4270-95cf-ff2fe2d9f569',
#  '38cb413f-ee75-4def-bd46-abc5b4b94b0c',
#  '72243b44-cd9c-4643-b8ae-90ae6df5492d',
#  '52d7bad4-64df-47aa-8def-e0a3187bba79',
#  '8dc328a9-2d87-4603-bbd7-acbe1ca3da07',
#  '5fd1cbef-8d6c-452a-bd56-f0a4fbcda73c',
#  'cf8d652a-bb0f-4161-a792-169ac50166eb',
#  'de812fc0-dade-4dbe-8ec3-cabe440d14a5',
#  'd71d9215-2705-481b-a11f-ae52dbd7a17b',
#  '11899466-d7da-4032-bbff-f92c291007c2',
#  '6dc87d9d-18a2-46d4-acfd-d1fac4a9cfc4',
#  '03cfe1b3-0c17-42a4-a2d4-b77d6afc63b0',
#  '3d2c8b8e-0e64-4e69-91b3-5ca80ec6b8b3',
#  'fa0cfca6-6819-44f6-8fb0-a35be5e19b97',
#  '028fc8c8-ee98-42f7-92aa-08f399121cdc',
#  '88bb199c-f548-4b8b-9e5e-2689462bb9a8',
#  '3f27985c-22d4-499d-8402-e8f51d9c39b7',
#  '0439fb47-34d8-4204-8e17-057fc006e0aa',
#  '1d50e50e-463c-4b3a-9f6c-8b4f405a9099',
#  '212318c0-ac47-496f-8337-3a494de5197d',
#  'f154667e-8e80-41c0-8897-8acf17301fe0',
#  '27145ce0-66d6-4186-99d1-d8fa574c849d',
#  'bfaf4007-3e9c-41a1-bb5f-3ce9cf5d53a0',
#  'bc9c883b-33e1-491b-9147-a20df361f102',
#  '226a64b4-07db-4775-93f5-5e0fc5ba9134',
#  '66a7521d-214f-468d-b124-09a4bb56960b',
#  'e028bb94-18e5-4a46-8888-8341e59b4dd0',
#  '6bd12e02-5d9c-40f2-bb8d-5b7d3d7c1600',
#  '8678eafd-fdb8-4221-90a5-c7221c36b8c7',
#  'f3f3309e-5ece-436b-b8fb-617ee519a3bb',
#  'fe936067-30bc-4c35-85b5-a1ed96ed8291',
#  '3cabf249-15a3-4d59-aad4-3069733e4e75',
#  '947e791f-e590-4365-8676-fafa26d85e79',
#  'd8b6cee4-d31b-40c5-970f-d5dbc15baf25',
#  '7a789da6-7c0c-4641-9e33-bd9c6491cdbf',
#  '573094bc-7a44-4b1a-a1a0-4df8afb639ab',
#  '036baafc-7fde-4024-a983-e6b48f844442',
#  '8203f73c-9fc1-4833-9bc4-ff66474c224b',
#  '23a061d2-426d-4549-96a7-74de6edbb917',
#  'ed954efb-1e22-424e-801d-8a653a888e14',
#  'e3c9cf17-f375-47cd-8514-8633516eba91',
#  '1f6e856a-80ad-485b-9843-e088309360c1',
#  '408d713f-1105-4ff9-a1db-b4c065fe281a',
#  '12e75cca-c621-4781-92b6-1796ab2be2bc',
#  '8426370e-57a7-4640-ae70-538617f96bb7',
#  '771c5cc0-ed5e-460f-a908-fca85d88ec05',
#  'cc6751f2-0d03-4c64-9849-66c7d672846b',
#  'a62e230c-c7ab-468c-a965-0ee11bda03ec',
#  '0fb9dc14-d79f-44e7-aecd-af5e8fb2d10a',
#  '85d7bd90-833c-4caf-abea-0c04d268e42c',
#  'a4ddfcf5-9384-49aa-9b9a-a26cd0eb49ad',
#  '71d1af08-798e-4962-8f5d-35de6e5610c6',
#  'efb0021b-c21c-4c39-8746-2e5188b08a3b',
#  '2010aa3c-a8f5-4b90-b736-700e6990643d',
#  '5ea50c32-86d4-4d85-be74-cf09b03665fc',
#  'f8d8fb31-afa6-4802-b020-3f16aa5a4fbb',
#  '34ec4950-616c-4e50-be80-21a6c29adde8',
#  '090839b3-a808-46e6-9ad7-291119d7998b',
#  'aa285020-d64a-47e4-a5c9-879ea487f111',
#  '9cc4a6a7-2ff2-4ea7-b34c-4c3a13d24f40',
#  'f228eb8a-61da-45c8-b520-581f4f2a7e40',
#  '2b238e63-0aab-425e-ace3-a8ec76dec605',
#  'c06017e0-f49e-405a-85b2-4292898ceaf6',
#  'ed4ca353-79ba-4a51-9794-83762e0eebf3',
#  'bbccd46d-b53d-40bd-aef0-49a67d34857e',
#  '7de8ce5a-35d0-4501-be7d-b39558eb3397',
#  '02cf7116-df78-44ba-8988-dc859ebe5190',
#  '608adbc0-84f7-41ef-92f4-7cd742d73596',
#  'c733c730-2a52-4032-8cb2-fa8b1f45b127',
#  '1e704568-c041-49c4-8948-fc2c316ce629',
#  'd6db130c-877c-4c93-b852-8ce65694d337',
#  '50a8d726-2588-493b-b6ed-e8a76f8d89ee',
#  '1a326b8b-ef4a-4d2d-b331-12b10fef82dc',
#  '5cf8f29b-7dd0-4483-8cf3-53e9b6dc46b6',
#  'c8a6c5ca-29e6-45cb-91f6-6933180d5a09',
#  '947d644a-74b2-41f6-84a6-19220eae579b',
#  'c15680a5-19ee-4f16-9bd6-812934b99fc6',
#  'dc5e79f8-86a9-472c-90ff-ae5573be71ae',
#  '3d74ee24-cd24-48a8-b06d-1fa49e1f1887',
#  '3e1a1cc9-6b8d-49cc-98ad-303a9d38ae4d',
#  '21fb8640-c07f-43b5-8315-c3025da483c3',
#  '50f03621-14a9-4fb3-8f7d-a31fc2415a4d',
#  '8ae5b460-ef67-4379-8d2e-1dec55b30a8f',
#  '1fab41c4-6453-4401-bb9e-cee61f9c75cb',
#  'baf56a70-f303-43a2-838d-3afd2228a0c4',
#  '2a015fb5-4be3-49c0-90c4-c605c6b2864f',
#  'e0f779e0-10bc-4805-8e5a-dd40f9243b86',
#  '78be060a-6d0b-42c0-9022-7b46c0a2f744',
#  'c6c2eafb-94c6-4f52-b345-0535e431ca18',
#  'f6c1d28e-3933-4f94-b63d-ac1066e9eeff',
#  '92182cdf-8285-4ca5-9d98-67bb42251339',
#  '99b06849-0869-4f3f-93d1-731b3889bf22',
#  '91da59f0-ca47-4e14-9d22-78d5cdfb0998',
#  'f253901e-02bb-41ca-a9e9-ddf89d9e3c03',
#  '61d63ff8-bc9c-4cbb-ade5-a12d5c1d5439',
#  '141ceced-a483-47b8-a13a-6c62a29311bb',
#  '8e2c53eb-920a-4044-921e-8d913220e322',
#  '1247bc3d-b537-4ee1-a59f-48367ab4bb2a',
#  '1a9bc7a5-591a-47f9-98ba-3382a7830985',
#  '4da24e5b-c8c4-4355-87e1-905d6f01fa10',
#  '42c78f9d-1fd2-4ccd-aa77-fe3e765e9ec1',
#  '0dda893d-cb71-4bf6-8122-e7c103e297c7',
#  '1af3de7c-862c-446b-804a-d2d5bf390d4c',
#  '3ad7acd1-24db-4a63-bc4e-a4fb87f0de3a',
#  '4e450c6e-37f6-4da8-b82e-ebeefc745140',
#  '3f5b0df5-3547-4377-9456-7fe5d985f6c4',
#  'd56647a1-4296-46d6-b3cb-b7c85e0bbaf3',
#  '50ea58d2-c0f9-4fc1-a59f-f804d3e0754b',
#  'b0a2ffb8-9a9d-4bc4-af6e-8a8473307f77',
#  '23582436-cf84-4385-8d42-3785a23c4567',
#  '361cbc67-5e3d-4a56-ba96-02b5d6391678',
#  'e879723b-5f8d-4553-b0a6-124bb0fe52c0',
#  'e1f09653-1cf0-4857-aef9-ed01f6dd5f64',
#  '2002038c-6c87-4bc3-92c3-3dac52b0251e',
#  '78557b04-eb99-4573-bb7e-ba813e83276a',
#  '33fe4b5c-3dc7-4e10-a339-da89601825c4',
#  '1517a334-545d-4530-94b0-512c8c1e0974',
#  '384213cc-8f2b-43e5-8f95-0cb844fa64d4',
#  '4fb0778b-dc30-4348-9060-70a167fa7dca',
#  '19982975-45fb-434e-9485-75c734aedcdd',
#  'b0952425-c432-4178-94c3-12d94648cb64',
#  '64387b21-6d49-4156-8850-ce8fdf76aab5',
#  '3122b171-bef6-4ea2-97a3-2f0bd7641a64',
#  '41ed09d6-5893-4981-8ed2-501421eb97c8',
#  'b857527c-e648-472b-97de-4c8d072ec47a',
#  '6a8d34a3-5af4-404c-97e5-876e9924a848',
# %%
def classify_product(product_descr):
    messages = [
        (
            "system",
            "You are a utility function in a python application program. Your job is to take a product description and return a 1 or 2 word category for the product along with 1 or 2 room names where you would find this product.",
        ),
        ("human", product_descr),
    ]
    response = llm.invoke(messages)
    return response.content

# %%
def query_orders(text, num_results = 1):
    results = vector_store.similarity_search(
    text,
    k=num_results,
    #filter={"Order Date":{"$gte": start_of_2024}},
)

    # Collect results in a list of dictionaries
    data = []

    for res in results:
        data.append({
            "Product Description": res.page_content,
            "Order Date": res.metadata.get('Order Date'),
            "Product Name": res.metadata.get('Product Name'),
            "Unit Price": res.metadata.get('Unit Price'),
            "ASIN": res.metadata.get('ASIN')
        })

    # Convert the list of dictionaries to a DataFrame
    df_results = pd.DataFrame(data)
    
    for index, row in df_results.iterrows():
        #print(f"Product Description: {row['Product Description']}")
        print(f"Product Name: {row['Product Name']}"),
        print(f"Order Date: {row['Order Date']}")
        print(f"ASIN: {row['ASIN']}"),
        print(classify_product(row['Product Name'])),
        print(f"Unit Price: {row['Unit Price']}\n")        
    return

# %%
query_text = "Clothes for sailing"
query_orders(query_text, 3)
# Out:
# Product Name: WindRider 3/4 Finger Performance Sailing Gloves
# Order Date: 2021-07-11T15:59:26Z
# ASIN: B06XKPZHXL
# Category: Sailing Gear
# Rooms: Dock, Marina
# Unit Price: 18.99
#
# Product Name: WindRider 3/4 Finger Performance Sailing Gloves - Kayak Canoe Paddling
# Order Date: 2021-07-11T15:58:13Z
# ASIN: B014TH8J8O
# Category: Sailing Gloves
# Room: Outdoors, Sports
# Unit Price: 18.99
#
# Product Name: MARCHWAY Floating Waterproof Dry Bag 5L/10L/20L/30L, Roll Top Sack Keeps Gear Dry for Kayaking, Rafting, Boating, Swimming, Camping, Hiking, Beach, Fishing (Bright Yellow, 10L)
# Order Date: 2021-07-12T15:54:42Z
# ASIN: B01N116D0C
# Category: Dry Bag
# Rooms: Outdoors, Water Activities
# Unit Price: 14.99

# %%
from langchain_openai import ChatOpenAI

# Initialize OpenAI client
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
print(response.content)
# Out:
# Category: Bathroom Cleaner
# Room: Bathroom, Toilet

# %%
from typing import Optional

from pydantic import BaseModel, Field

# %%
class OrderItem(BaseModel):
    category: str = Field(description="The category of the item (home goods, bath supplies, sports equipment, etc)")
    room: str = Field(description="The room where this item is most likely to be found")

# %%
structured_llm = llm.with_structured_output(OrderItem)

# %%
item_response = structured_llm.invoke("MARCHWAY Floating Waterproof Dry Bag 5L/10L/20L/30L, Roll Top Sack Keeps Gear Dry for Kayaking, Rafting, Boating, Swimming, Camping, Hiking, Beach, Fishing (Bright Yellow, 10L)")

# %%
item_response.room
# Out:
# 'outdoor'

# %%
item_response.category
# Out:
# 'sports equipment'

# %%
df_brief_small.head()
# Out:
#                     Order Date  Unit Price  \
# 122  2023-12-31 17:21:27+00:00      189.99
# 9    2024-08-29 12:53:41+00:00       39.97
# 993  2018-06-05 14:35:10+00:00       12.93
# 1373 2011-02-11 01:23:52+00:00       33.36
# 149  2023-11-24 22:45:19+00:00       16.99
#
#                                            Product Name        ASIN
# 122   Cricut Joy Machine Rainbow Permanent Vinyl, St...  B0B7XS1ZR5
# 9     Ultra Concentrated Organic Mushroom Coffee 3,5...  B0D41N4J1Y
# 993   Tom's of Maine Natural Long Lasting Men's Deod...  B00LITYJYU
# 1373    UTG Covert Homeland Security Gun Case (32-Inch)  B001WJ6O9E
# 149   Amazon Basics Dishwasher Detergent Pacs, Fresh...  B09CLR75K6

# %%
start_date = pd.to_datetime('2020-01-01', utc=True)
end_date = pd.to_datetime('2024-10-01', utc=True)

df_filtered = df_brief[(df_brief['Order Date'] >= start_date) & (df_brief['Order Date'] < end_date)]

# %%
df_new = df_filtered.copy()
df_new['Category'] = None
df_new['Room'] = None

# %%
for index, row in df_new.iterrows():
    description = row[description_column]
    item_response = structured_llm.invoke(description)
    category = item_response.category
    room = item_response.room
    #print(f"Adding category: {category}")
    df_new.loc[index,'Category'] = category
    #print(f"Adding room: {room}")
    df_new.loc[index,'Room'] = room

# %%
df_new.dtypes
# Out:
# Order Date      datetime64[ns, UTC]
# Unit Price                  float64
# Product Name                 object
# ASIN                         object
# Category                     object
# Room                         object
# dtype: object

# %%
df2 = df_brief_small.copy()

# %%
df2['Order Date'] = df2['Order Date'].str.replace(r'\.\d+', '', regex=True)

df2['Order Date 2'] = pd.to_datetime(df2['Order Date'], utc=True)

# %%
df2.head()
# Out:
#                 Order Date  Unit Price  \
# 315   2023-01-16T18:51:34Z       16.68
# 1106  2017-06-05T19:05:54Z       11.99
# 999   2018-05-31T00:18:01Z       29.95
# 752   2020-09-11T14:52:30Z        4.89
# 1141  2017-02-09T23:07:28Z      184.95
#
#                                            Product Name        ASIN  \
# 315   Scrubbing Bubbles Fresh Brush Flushables Refil...  B07YCZ3N36
# 1106  Choetech T511 7.5W Qi Wireless Charging Pad wi...  B00C40OG22
# 999   Antarctic Krill Oil (Double Strength) 1000mg p...  B00IP1E3O0
# 752   TERRO T300 Liquid Ant Bait Ant Killer, 6 Bait ...  B000HJBKMQ
# 1141  TP-Link AC3150 Wireless Wi-Fi Gigabit Router w...  B01AK9TC0Y
#
#                   Order Date 2
# 315  2023-01-16 18:51:34+00:00
# 1106 2017-06-05 19:05:54+00:00
# 999  2018-05-31 00:18:01+00:00
# 752  2020-09-11 14:52:30+00:00
# 1141 2017-02-09 23:07:28+00:00

# %%
null_mask = df2.isnull().any(axis=1)
null_rows = df2[null_mask]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [Order Date, Unit Price, Product Name, ASIN, Order Date 2]
# Index: []

# %%
pd.to_datetime('2022-10-02T05:24:49.872Z')
# Out:
# Timestamp('2022-10-02 05:24:49.872000+0000', tz='UTC')

# %%
df_filtered.shape
# Out:
# (121, 4)

# %%
df_filtered.head()
# Out:
#                  Order Date  Unit Price  \
# 0 2024-09-17 23:38:02+00:00       16.99
# 1 2024-09-16 00:30:45+00:00       80.85
# 2 2024-09-14 17:20:46+00:00       17.04
# 3 2024-09-12 02:04:33+00:00       15.26
# 4 2024-09-11 20:09:36+00:00        7.13
#
#                                         Product Name        ASIN
# 0  Blender Replacement 6 Fins for Ninja Blade 16 ...  B089QFC5QH
# 1  Optimum Nutrition Gold Standard 100% Whey Prot...  B000QSTBNS
# 2  Old Path White Clouds: Walking in the Footstep...  0938077260
# 3  REACH Listerine Ultraclean Dental Floss 6-Pack...  B00LITWSW0
# 4  StarKist Chunk Light Tuna in Water, 5 oz (8 Pa...  B00FWUO2IE

# %%
df_new['Order Date'] = df_new['Order Date'].dt.tz_localize(None)

# %%
df_new.head()
# Out:
#                  Order Date  Unit Price  \
# 0 2024-09-17 23:38:02+00:00       16.99
# 1 2024-09-16 00:30:45+00:00       80.85
# 2 2024-09-14 17:20:46+00:00       17.04
# 3 2024-09-12 02:04:33+00:00       15.26
# 4 2024-09-11 20:09:36+00:00        7.13
#
#                                         Product Name        ASIN  \
# 0  Blender Replacement 6 Fins for Ninja Blade 16 ...  B089QFC5QH
# 1  Optimum Nutrition Gold Standard 100% Whey Prot...  B000QSTBNS
# 2  Old Path White Clouds: Walking in the Footstep...  0938077260
# 3  REACH Listerine Ultraclean Dental Floss 6-Pack...  B00LITWSW0
# 4  StarKist Chunk Light Tuna in Water, 5 oz (8 Pa...  B00FWUO2IE
#
#              Category         Room
# 0  kitchen appliances      kitchen
# 1    sports nutrition          gym
# 2               books  living room
# 3       bath supplies     bathroom
# 4        canned goods       pantry

# %%
# Write to file

df_new.to_csv('orders_out.csv', index=False)

# %%
df_to_store = df_new

# %%
df_to_store.head(10)
# Out:
#                  Order Date  Unit Price  \
# 0 2024-09-17 23:38:02+00:00       16.99
# 1 2024-09-16 00:30:45+00:00       80.85
# 2 2024-09-14 17:20:46+00:00       17.04
# 3 2024-09-12 02:04:33+00:00       15.26
# 4 2024-09-11 20:09:36+00:00        7.13
# 5 2024-09-11 20:07:02+00:00       11.19
# 6 2024-09-11 17:46:51+00:00       23.49
# 7 2024-08-31 18:14:10+00:00       38.99
# 8 2024-08-31 16:01:40+00:00       10.44
# 9 2024-08-29 12:53:41+00:00       39.97
#
#                                         Product Name        ASIN  \
# 0  Blender Replacement 6 Fins for Ninja Blade 16 ...  B089QFC5QH
# 1  Optimum Nutrition Gold Standard 100% Whey Prot...  B000QSTBNS
# 2  Old Path White Clouds: Walking in the Footstep...  0938077260
# 3  REACH Listerine Ultraclean Dental Floss 6-Pack...  B00LITWSW0
# 4  StarKist Chunk Light Tuna in Water, 5 oz (8 Pa...  B00FWUO2IE
# 5       Kewpie DEEP-ROASTED SESAME DRESSING (16.9OZ)  B08M9PR731
# 6  Energizer 9V Batteries, Ultimate Lithium, Orig...  B01684J7P0
# 7  FelizMax Crescent Zafu Meditation Pillow, 44x2...  B07QSTGBMM
# 8               SKIPPY Creamy Peanut Butter, 5 Pound  B00LPE5EZQ
# 9  Ultra Concentrated Organic Mushroom Coffee 3,5...  B0D41N4J1Y
#
#              Category         Room
# 0  kitchen appliances      kitchen
# 1    sports nutrition          gym
# 2               books  living room
# 3       bath supplies     bathroom
# 4         canned food       pantry
# 5          condiments      kitchen
# 6           batteries      utility
# 7       bath supplies  living room
# 8                food      kitchen
# 9           beverages      kitchen

# %%
df_to_store.shape
# Out:
# (821, 6)
